# %%
#Importamos la libreria Matplotlib
import matplotlib.pyplot as plt
#Importamos la libreria Numpy
import pandas as pd

# %%
#Cargamos el archivo SP500
df = pd.read_csv(r"C:\Users\aviscarra\Documents\Curso\Python\AnalisisDeDatos\Recursos\Datasets+Data+Science\1.4\SP500_data.csv", encoding="ISO-8859-1",delimiter=",")

# %%
#Presentamos los 10 primeros registros
df.head(10)
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume
# 0  1927-12-30  17.660000  17.660000  17.660000  17.660000  17.660000       0
# 1  1928-01-03  17.760000  17.760000  17.760000  17.760000  17.760000       0
# 2  1928-01-04  17.719999  17.719999  17.719999  17.719999  17.719999       0
# 3  1928-01-05  17.549999  17.549999  17.549999  17.549999  17.549999       0
# 4  1928-01-06  17.660000  17.660000  17.660000  17.660000  17.660000       0
# 5  1928-01-09  17.500000  17.500000  17.500000  17.500000  17.500000       0
# 6  1928-01-10  17.370001  17.370001  17.370001  17.370001  17.370001       0
# 7  1928-01-11  17.350000  17.350000  17.350000  17.350000  17.350000       0
# 8  1928-01-12  17.469999  17.469999  17.469999  17.469999  17.469999       0
# 9  1928-01-13  17.580000  17.580000  17.580000  17.580000  17.580000       0

# %%
#Graficamos en funcion de la columna Close
df["Close"].plot()
# Out:
# <Axes: >

# %%
#Registramos en el Indice los valores de Date
df.index = df["Date"]

# %%
#Verificamos que se hayan insertado
df.head(10)
# Out:
#                   Date       Open       High        Low      Close  Adj Close  \
# Date
# 1927-12-30  1927-12-30  17.660000  17.660000  17.660000  17.660000  17.660000
# 1928-01-03  1928-01-03  17.760000  17.760000  17.760000  17.760000  17.760000
# 1928-01-04  1928-01-04  17.719999  17.719999  17.719999  17.719999  17.719999
# 1928-01-05  1928-01-05  17.549999  17.549999  17.549999  17.549999  17.549999
# 1928-01-06  1928-01-06  17.660000  17.660000  17.660000  17.660000  17.660000
# 1928-01-09  1928-01-09  17.500000  17.500000  17.500000  17.500000  17.500000
# 1928-01-10  1928-01-10  17.370001  17.370001  17.370001  17.370001  17.370001
# 1928-01-11  1928-01-11  17.350000  17.350000  17.350000  17.350000  17.350000
# 1928-01-12  1928-01-12  17.469999  17.469999  17.469999  17.469999  17.469999
# 1928-01-13  1928-01-13  17.580000  17.580000  17.580000  17.580000  17.580000
#
#             Volume
# Date
# 1927-12-30       0
# 1928-01-03       0
# 1928-01-04       0
# ...

# %%
#Graficamos nuevamente en funcion de la columna Close
df["Close"].plot()
# Out:
# <Axes: xlabel='Date'>
