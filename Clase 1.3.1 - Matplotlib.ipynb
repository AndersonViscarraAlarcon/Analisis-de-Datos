# %%
#Importamos la libreria Matplotlyb
import matplotlib.pyplot as plt

# %%
#Establecemos la variable de X
año = [2020, 2021, 2022]

# %%
#Establecemos la variable de y
valor = [5, 6, 9]

# %%
#Generamos una grafica de lineas
plt.plot(año, valor)

# %%
#Generamos una grafica de puntos
plt.scatter(año, valor)
